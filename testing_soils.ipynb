# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = gpd.read_file("src/soils/shapes/30169_L93.shp")

# %%
df
# Out:
#              AREA  PERIMETER  SOIL_  SOIL_ID     SMU  \
# 0      33602000.0   59377.90      2    12802  330107
# 1     627837000.0  142436.00      3    12833  330086
# 2      22488700.0   24251.40      4    12951  320076
# 3     137778000.0  110800.00      5    12971  330177
# 4     183099000.0   89677.00      6    12989  330685
# ...           ...        ...    ...      ...     ...
# 3511   11148800.0   18141.30   3513    24183  330099
# 3512   35259600.0   26246.40   3514    24249  330154
# 3513   12312300.0   18989.60   3515    24258  330677
# 3514     774387.0    3693.05   3516    24279  390267
# 3515     542311.0    3552.75   3517    24297  390267
#
#                                                geometry
# 0     POLYGON ((668088.739 7110807.413, 668351.877 7...
# 1     POLYGON ((668694.183 7108785.403, 669195.218 7...
# 2     POLYGON ((668862.463 7099548.802, 669579.525 7...
# 3     POLYGON ((668862.463 7099548.802, 669199.192 7...
# ...

# %%
df["SMU"].nunique()
# Out:
# 321

# %%
df = df.to_crs("EPSG:4326")

# %%
df.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(10, 10))

df.plot(ax=ax, column="SMU", legend=True)
# Out:
# <Axes: >

# %%
france = gpd.read_file("src/departements.geojson")

# %%
print(france.crs)
france.plot()
# Out:
# EPSG:4326
# <Axes: >

# %%
grid = np.load("src/grid.npz")

# %%
grid
# Out:
# NpzFile 'src/grid.npz' with keys: lon, lat

# %%
fig, ax = plt.subplots(figsize=(15, 15))
df.plot(ax=ax, column="SMU", legend=True)
ax.scatter(grid["lon"], grid["lat"], s=0.01)
